# %% [markdown]
# Importing all the required modules

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from wordcloud import WordCloud, STOPWORDS
from collections import Counter
import string

# %%
df = pd.read_csv(r'C:\Users\RAHUL\Downloads\Capstone 2\SMSSpamCollection', sep='\t', names=['label', 'message'])

# %%
df.head()
# Out:
#   label                                            message
# 0   ham  Go until jurong point, crazy.. Available only ...
# 1   ham                      Ok lar... Joking wif u oni...
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3   ham  U dun say so early hor... U c already then say...
# 4   ham  Nah I don't think he goes to usf, he lives aro...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5572 entries, 0 to 5571
# Data columns (total 2 columns):
# label      5572 non-null object
# message    5572 non-null object
# dtypes: object(2)
# memory usage: 87.1+ KB

# %%
df.describe()
# Out:
#        label                 message
# count   5572                    5572
# unique     2                    5169
# top      ham  Sorry, I'll call later
# freq    4825                      30

# %%
df.groupby("label").describe()
# Out:
#       message
#         count unique                                                top freq
# label
# ham      4825   4516                             Sorry, I'll call later   30
# spam      747    653  Please call our customer service representativ...    4

# %%
df['message'].describe()
# Out:
# count                       5572
# unique                      5169
# top       Sorry, I'll call later
# freq                          30
# Name: message, dtype: object

# %%
df['message'].apply(len).describe()
# Out:
# count    5572.000000
# mean       80.489950
# std        59.942907
# min         2.000000
# 25%        36.000000
# 50%        62.000000
# 75%       122.000000
# max       910.000000
# Name: message, dtype: float64

# %%
df[df.message.apply(len)==2]
# Out:
#      label message
# 1925   ham      Ok
# 3051   ham      Ok
# 4498   ham      Ok
# 5357   ham      Ok

# %%
df[df.message.apply(len)==2]['message'].value_counts()
# Out:
# Ok    4
# Name: message, dtype: int64

# %%
df[df.message.apply(len)==910]['message'].iloc[0]
# Out:
# "For me the love should start with attraction.i should feel that I need her every time around me.she should be the first thing which comes in my thoughts.I would start the day and end it with her.she should be there every time I dream.love will be then when my every breath has her name.my life should happen around her.my life will be named to her.I would cry for her.will give all my happiness and take all her sorrows.I will be ready to fight with anyone for her.I will be in love when I will be doing the craziest things for her.love will be when I don't have to proove anyone that my girl is the most beautiful lady on the whole planet.I will always be singing praises for her.love will be when I start up making chicken curry and end up makiing sambar.life will be the most beautiful then.will get every morning and thank god for the day because she is with me.I would like to say a lot..will tell later.."

# %%
sns.countplot(df['label'])

# %%
df['label'].value_counts()
# Out:
# ham     4825
# spam     747
# Name: label, dtype: int64

# %%
distinct = df['message'].value_counts()
sns.countplot(x=distinct, data=df)

# %%
spam_perc = (747/5572) * 100
print(spam_perc)
# Out:
# 13.406317300789663

# %%
ham_perc = 100 - spam_perc

# %%
label = ['spam','ham']
size = [spam_perc,ham_perc]
explodes = (0.15, 0)

# %%
plt.pie(size, explode=explodes,labels=label,autopct='%1.1f%%',shadow=True,startangle=65)
plt.show()

# %%
comment_words = ' '
stopwords = set(STOPWORDS) 

for val in df.message: 
      
    # typecaste each val to string 
    val = str(val) 
  
    # split the value 
    tokens = val.split() 
      
    # Converts each token into lowercase 
    for i in range(len(tokens)): 
        tokens[i] = tokens[i].lower() 
          
    for words in tokens: 
        comment_words = comment_words + words + ' '
  
  
wordcloud = WordCloud(width = 800, height = 800, 
                background_color ='white', 
                stopwords = stopwords, 
                min_font_size = 10).generate(comment_words) 
  
# plot the WordCloud image                        
plt.figure(figsize = (8, 8), facecolor = None) 
plt.imshow(wordcloud) 
plt.axis("off") 
plt.tight_layout(pad = 0) 
  
plt.show()

# %%
spam_im = df.message[df.label=='spam']

# %%
spam_im.head()
# Out:
# 2     Free entry in 2 a wkly comp to win FA Cup fina...
# 5     FreeMsg Hey there darling it's been 3 week's n...
# 8     WINNER!! As a valued network customer you have...
# 9     Had your mobile 11 months or more? U R entitle...
# 11    SIX chances to win CASH! From 100 to 20,000 po...
# Name: message, dtype: object

# %%
comment_words1 = ' '
stopwords = set(STOPWORDS) 

for val in spam_im: 
      
    # typecaste each val to string 
    val = str(val) 
  
    # split the value 
    tokens = val.split() 
      
    # Converts each token into lowercase 
    for i in range(len(tokens)): 
        tokens[i] = tokens[i].lower() 
          
    for words in tokens: 
        comment_words1 = comment_words1 + words + ' '
  
  
wordcloud = WordCloud(width = 800, height = 800, 
                background_color ='white', 
                stopwords = stopwords, 
                min_font_size = 10).generate(comment_words1) 
  
# plot the WordCloud image                        
plt.figure(figsize = (8, 8), facecolor = None) 
plt.imshow(wordcloud) 
plt.axis("off") 
plt.tight_layout(pad = 0) 
  
plt.show()

# %%
ham_im = df.message[df['label']=='ham']

# %%
comment_words2 = ' '
stopwords = set(STOPWORDS) 

for val in ham_im: 
      
    # typecaste each val to string 
    val = str(val) 
  
    # split the value 
    tokens = val.split() 
      
    # Converts each token into lowercase 
    for i in range(len(tokens)): 
        tokens[i] = tokens[i].lower() 
          
    for words in tokens: 
        comment_words2 = comment_words2 + words + ' '
  
  
wordcloud = WordCloud(width = 800, height = 800, 
                background_color ='white', 
                stopwords = stopwords, 
                min_font_size = 10).generate(comment_words2) 
  
# plot the WordCloud image                        
plt.figure(figsize = (8, 8), facecolor = None) 
plt.imshow(wordcloud) 
plt.axis("off") 
plt.tight_layout(pad = 0) 
  
plt.show()

# %%
spam_im.value_counts()
# Out:
# Please call our customer service representative on FREEPHONE 0808 145 4742 between 9am-11pm as you have WON a guaranteed £1000 cash or £5000 prize!                          4
# I don't know u and u don't know me. Send CHAT to 86688 now and let's find each other! Only 150p/Msg rcvd. HG/Suite342/2Lands/Row/W1J6HL LDN. 18 years or over.               3
# Camera - You are awarded a SiPix Digital Camera! call 09061221066 fromm landline. Delivery within 28 days.                                                                   3
# FREE for 1st week! No1 Nokia tone 4 ur mob every week just txt NOKIA to 8007 Get txting and tell ur mates www.getzed.co.uk POBox 36504 W45WQ norm150p/tone 16+               3
# HMV BONUS SPECIAL 500 pounds of genuine HMV vouchers to be won. Just answer 4 easy questions. Play Now! Send HMV to 86688 More info:www.100percent-real.com                  3
# Loan for any purpose £500 - £75,000. Homeowners + Tenants welcome. Have you been previously refused? We can still help. Call Free 0800 1956669 or text back 'help'           3
# You are awarded a SiPix Digital Camera! call 09061221061 from landline. Delivery within 28days. T Cs Box177. M221BP. 2yr warranty. 150ppm. 16 . p p£3.99                     2
# +123 Congratulations - in this week's competition draw u have won the £1450 prize to claim just call 09050002311 b4280703. T&Cs/stop SMS 08718727868. Over 18 only 150ppm    2
# Wan2 win a Meet+Greet with Westlife 4 U or a m8? They are currently on what tour? 1)Unbreakable, 2)Untamed, 3)Unkempt. Text 1,2 or 3 to 83049. Cost 50p +std text            2
# You won't believe it but it's true. It's Incredible Txts! Reply G now to learn truly amazing things that will blow your mind. From O2FWD only 18p/txt                        2
# Final Chance! Claim ur £150 worth of discount vouchers today! Text YES to 85023 now! SavaMob, member offers mobile! T Cs SavaMob POBOX84, M263UZ. £3.00 Subs 16              2
# No 1 POLYPHONIC tone 4 ur mob every week! Just txt PT2 to 87575. 1st Tone FREE ! so get txtin now and tell ur friends. 150p/tone. 16 reply HL 4info                          2
# Someone U know has asked our dating service 2 contact you! Cant Guess who? CALL 09058091854 NOW all will be revealed. PO BOX385 M6 6WU                                       2
# You are a winner U have been specially selected 2 receive £1000 cash or a 4* holiday (flights inc) speak to a live operator 2 claim 0871277810810                            2
# YOU ARE CHOSEN TO RECEIVE A £350 AWARD! Pls call claim number 09066364311 to collect your award which you are selected to receive as a valued mobile customer.               2
# Free Top ringtone -sub to weekly ringtone-get 1st week free-send SUBPOLY to 81618-?3 per week-stop sms-08718727870                                                           2
# Urgent UR awarded a complimentary trip to EuroDisinc Trav, Aco&Entry41 Or £1000. To claim txt DIS to 87121 18+6*£1.50(moreFrmMob. ShrAcomOrSglSuplt)10, LS1 3AJ              2
# Get your garden ready for summer with a FREE selection of summer bulbs and seeds worth £33:50 only with The Scotsman this Saturday. To stop go2 notxt.co.uk                  2
# URGENT! Your Mobile number has been awarded with a £2000 prize GUARANTEED. Call 09061790121 from land line. Claim 3030. Valid 12hrs only 150ppm                              2
# Got what it takes 2 take part in the WRC Rally in Oz? U can with Lucozade Energy! Text RALLY LE to 61200 (25p), see packs or lucozade.co.uk/wrc & itcould be u!              2
# U can WIN £100 of Music Gift Vouchers every week starting NOW Txt the word DRAW to 87066 TsCs www.Idew.com SkillGame, 1Winaweek, age16. 150ppermessSubscription              2
# December only! Had your mobile 11mths+? You are entitled to update to the latest colour camera mobile for Free! Call The Mobile Update Co FREE on 08002986906                2
# Free entry in 2 a weekly comp for a chance to win an ipod. Txt POD to 80182 to get entry (std txt rate) T&C's apply 08452810073 for details 18+                              2
# Free entry in 2 a wkly comp to win FA Cup final tkts 21st May 2005. Text FA to 87121 to receive entry question(std txt rate)T&C's apply 08452810075over18's                  2
# URGENT! We are trying to contact U. Todays draw shows that you have won a £800 prize GUARANTEED. Call 09050001808 from land line. Claim M95. Valid12hrs only                 2
# Bloomberg -Message center +447797706009 Why wait? Apply for your future http://careers. bloomberg.com                                                                        2
# Congrats! 1 year special cinema pass for 2 is yours. call 09061209465 now! C Suprman V, Matrix3, StarWars3, etc all 4 FREE! bx420-ip4-5we. 150pm. Dont miss out!             2
# Great NEW Offer - DOUBLE Mins & DOUBLE Txt on best Orange tariffs AND get latest camera phones 4 FREE! Call MobileUpd8 free on 08000839402 NOW! or 2stoptxt T&Cs             2
# Not heard from U4 a while. Call 4 rude chat private line 01223585334 to cum. Wan 2C pics of me gettin shagged then text PIX to 8552. 2End send STOP 8552 SAM xxx             2
# Double mins and txts 4 6months FREE Bluetooth on Orange. Available on Sony, Nokia Motorola phones. Call MobileUpd8 on 08000839402 or call2optout/N9DX                        2
#                                                                                                                                                                             ..
# For ur chance to win a £250 cash every wk TXT: ACTION to 80608. T's&C's www.movietrivia.tv custcare 08712405022, 1x150p/wk                                                   1
# Dear Voucher Holder, 2 claim this weeks offer, at your PC go to http://www.e-tlp.co.uk/expressoffer Ts&Cs apply.2 stop texts txt STOP to 80062.                              1
# You are being ripped off! Get your mobile content from www.clubmoby.com call 08717509990 poly/true/Pix/Ringtones/Games six downloads for only 3                              1
# URGENT! Last weekend's draw shows that you have won £1000 cash or a Spanish holiday! CALL NOW 09050000332 to claim. T&C: RSTM, SW7 3SS. 150ppm                               1
# Dear Voucher Holder, To claim this weeks offer, at you PC please go to http://www.e-tlp.co.uk/reward. Ts&Cs apply.                                                           1
# Ur ringtone service has changed! 25 Free credits! Go to club4mobiles.com to choose content now! Stop? txt CLUB STOP to 87070. 150p/wk Club4 PO Box1146 MK45 2WT              1
# Dorothy@kiefer.com (Bank of Granite issues Strong-Buy) EXPLOSIVE PICK FOR OUR MEMBERS *****UP OVER 300% *********** Nasdaq Symbol CDGT That is a $5.00 per..                 1
# URGENT! We are trying to contact U Todays draw shows that you have won a £800 prize GUARANTEED. Call 09050000460 from land line. Claim J89. po box245c2150pm                 1
# WIN a £200 Shopping spree every WEEK Starting NOW. 2 play text STORE to 88039. SkilGme. TsCs08714740323 1Winawk! age16 £1.50perweeksub.                                      1
# Thanks for your ringtone order, reference number X49.Your mobile will be charged 4.50. Should your tone not arrive please call customer services 09065989182                 1
# U have a secret admirer who is looking 2 make contact with U-find out who they R*reveal who thinks UR so special-call on 09058094594                                         1
# A link to your picture has been sent. You can also use http://alto18.co.uk/wave/wave.asp?o=44345                                                                             1
# 500 New Mobiles from 2004, MUST GO! Txt: NOKIA to No: 89545 & collect yours today!From ONLY £1 www.4-tc.biz 2optout 087187262701.50gbp/mtmsg18                               1
# URGENT! This is the 2nd attempt to contact U!U have WON £1000CALL 09071512432 b4 300603t&csBCM4235WC1N3XX.callcost150ppmmobilesvary. max£7. 50                               1
# You can stop further club tones by replying "STOP MIX" See my-tone.com/enjoy. html for terms. Club tones cost GBP4.50/week. MFL, PO Box 1146 MK45 2WT (2/3)                  1
# Santa calling! Would your little ones like a call from Santa Xmas Eve? Call 09077818151 to book you time. Calls1.50ppm last 3mins 30s T&C www.santacalling.com               1
# I'd like to tell you my deepest darkest fantasies. Call me 09094646631 just 60p/min. To stop texts call 08712460324 (nat rate)                                               1
# For taking part in our mobile survey yesterday! You can now have 500 texts 2 use however you wish. 2 get txts just send TXT to 80160 T&C www.txt43.com 1.50p                 1
# Do you want a new Video phone? 600 anytime any network mins 400 Inclusive Video calls AND downloads 5 per week Free delTOMORROW call 08002888812 or reply NOW                1
# Message Important information for O2 user. Today is your lucky day! 2 find out why log onto http://www.urawinner.com there is a fantastic surprise awaiting you              1
# Good Luck! Draw takes place 28th Feb 06. Good Luck! For removal send STOP to 87239 customer services 08708034412                                                             1
# Gr8 Poly tones 4 ALL mobs direct 2u rply with POLY TITLE to 8007 eg POLY BREATHE1 Titles: CRAZYIN, SLEEPINGWITH, FINEST, YMCA :getzed.co.uk POBox365O4W45WQ 300p             1
# Not heard from U4 a while. Call me now am here all night with just my knickers on. Make me beg for it like U did last time 01223585236 XX Luv Nikiyu4.net                    1
# Oh my god! I've found your number again! I'm so glad, text me back xafter this msgs cst std ntwk chg £1.50                                                                   1
# Adult 18 Content Your video will be with you shortly                                                                                                                         1
# Ur TONEXS subscription has been renewed and you have been charged £4.50. You can choose 10 more polys this month. www.clubzed.co.uk *BILLING MSG*                            1
# Do you realize that in about 40 years, we'll have thousands of old ladies running around with tattoos?                                                                       1
# Free msg: Single? Find a partner in your area! 1000s of real people are waiting to chat now!Send CHAT to 62220Cncl send STOPCS 08717890890£1.50 per msg                      1
# Congratulations ur awarded 500 of CD vouchers or 125gift guaranteed & Free entry 2 100 wkly draw txt MUSIC to 87066                                                          1
# FREE entry into our £250 weekly comp just send the word WIN to 80086 NOW. 18 T&C www.txttowin.co.uk                                                                          1
# Name: message, Length: 653, dtype: int64

# %%
ham_im.value_counts()
# Out:
# Sorry, I'll call later                                                                                                                                                                                                                                                                                                                                                                                                                                          30
# I cant pick the phone right now. Pls send a message                                                                                                                                                                                                                                                                                                                                                                                                             12
# Ok...                                                                                                                                                                                                                                                                                                                                                                                                                                                           10
# Say this slowly.? GOD,I LOVE YOU &amp; I NEED YOU,CLEAN MY HEART WITH YOUR BLOOD.Send this to Ten special people &amp; u c miracle tomorrow, do it,pls,pls do it...                                                                                                                                                                                                                                                                                              4
# Okie                                                                                                                                                                                                                                                                                                                                                                                                                                                             4
# Ok.                                                                                                                                                                                                                                                                                                                                                                                                                                                              4
# Ok                                                                                                                                                                                                                                                                                                                                                                                                                                                               4
# Wen ur lovable bcums angry wid u, dnt take it seriously.. Coz being angry is d most childish n true way of showing deep affection, care n luv!.. kettoda manda... Have nice day da.                                                                                                                                                                                                                                                                              4
# Your opinion about me? 1. Over 2. Jada 3. Kusruthi 4. Lovable 5. Silent 6. Spl character 7. Not matured 8. Stylish 9. Simple Pls reply..                                                                                                                                                                                                                                                                                                                         4
# 7 wonders in My WORLD 7th You 6th Ur style 5th Ur smile 4th Ur Personality 3rd Ur Nature 2nd Ur SMS and 1st "Ur Lovely Friendship"... good morning dear                                                                                                                                                                                                                                                                                                          4
# Howz that persons story                                                                                                                                                                                                                                                                                                                                                                                                                                          3
# I'm at home. Please call                                                                                                                                                                                                                                                                                                                                                                                                                                         3
# Did u got that persons story                                                                                                                                                                                                                                                                                                                                                                                                                                     3
# I wnt to buy a BMW car urgently..its vry urgent.but hv a shortage of  &lt;#&gt; Lacs.there is no source to arng dis amt. &lt;#&gt; lacs..thats my prob                                                                                                                                                                                                                                                                                                           3
# Love you aathi..love u lot..                                                                                                                                                                                                                                                                                                                                                                                                                                     3
# Okie...                                                                                                                                                                                                                                                                                                                                                                                                                                                          3
# K. I will sent it again                                                                                                                                                                                                                                                                                                                                                                                                                                          3
# Solve d Case : A Man Was Found Murdered On  &lt;DECIMAL&gt; . &lt;#&gt;  AfterNoon. 1,His wife called Police. 2,Police questioned everyone. 3,Wife: Sir,I was sleeping, when the murder took place. 4.Cook: I was cooking. 5.Gardener: I was picking vegetables. 6.House-Maid: I went 2 d post office. 7.Children: We went 2 play. 8.Neighbour: We went 2 a marriage. Police arrested d murderer Immediately. Who's It? Reply With Reason, If U r Brilliant.     3
# Ok.ok ok..then..whats ur todays plan                                                                                                                                                                                                                                                                                                                                                                                                                             3
# Watching cartoon, listening music &amp; at eve had to go temple &amp; church.. What about u?                                                                                                                                                                                                                                                                                                                                                                     3
# New Theory: Argument wins d SITUATION, but loses the PERSON. So dont argue with ur friends just.. . . . kick them &amp; say, I'm always correct.!                                                                                                                                                                                                                                                                                                                3
# I dont thnk its a wrong calling between us                                                                                                                                                                                                                                                                                                                                                                                                                       3
# Prabha..i'm soryda..realy..frm heart i'm sory                                                                                                                                                                                                                                                                                                                                                                                                                    3
# What Today-sunday..sunday is holiday..so no work..                                                                                                                                                                                                                                                                                                                                                                                                               3
# Gud mrng dear hav a nice day                                                                                                                                                                                                                                                                                                                                                                                                                                     3
# Honeybee Said: *I'm d Sweetest in d World* God Laughed &amp; Said: *Wait,U Havnt Met d Person Reading This Msg* MORAL: Even GOD Can Crack Jokes! GM+GN+GE+GN:)                                                                                                                                                                                                                                                                                                   3
# 1) Go to write msg 2) Put on Dictionary mode 3)Cover the screen with hand, 4)Press  &lt;#&gt; . 5)Gently remove Ur hand.. Its interesting..:)                                                                                                                                                                                                                                                                                                                    3
# No calls..messages..missed calls                                                                                                                                                                                                                                                                                                                                                                                                                                 3
# I'm at work. Please call                                                                                                                                                                                                                                                                                                                                                                                                                                         3
# No no. I will check all rooms befor activities                                                                                                                                                                                                                                                                                                                                                                                                                   3
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                 ..
# Aww you must be nearly dead!Well Jez isComing over toDo some workAnd that whillTake forever!                                                                                                                                                                                                                                                                                                                                                                     1
# Studying. But i.ll be free next weekend.                                                                                                                                                                                                                                                                                                                                                                                                                         1
# Yes i thought so. Thanks.                                                                                                                                                                                                                                                                                                                                                                                                                                        1
# Where can download clear movies. Dvd copies.                                                                                                                                                                                                                                                                                                                                                                                                                     1
# Ok. There may be a free gym about.                                                                                                                                                                                                                                                                                                                                                                                                                               1
# Ok i also wan 2 watch e 9 pm show...                                                                                                                                                                                                                                                                                                                                                                                                                             1
# Congrats ! Treat pending.i am not on mail for 2 days.will mail once thru.Respect mother at home.check mails.                                                                                                                                                                                                                                                                                                                                                     1
# U too...                                                                                                                                                                                                                                                                                                                                                                                                                                                         1
# 1's finish meeting call me.                                                                                                                                                                                                                                                                                                                                                                                                                                      1
# I cant keep talking to people if am not sure i can pay them if they agree to price. So pls tell me what you want to really buy and how much you are willing to pay                                                                                                                                                                                                                                                                                               1
# K, wen ur free come to my home and also tel vikky i hav sent mail to him also.. Better come evening il be free today aftr 6pm..:-)                                                                                                                                                                                                                                                                                                                               1
# You please give us connection today itself before  &lt;DECIMAL&gt;  or refund the bill                                                                                                                                                                                                                                                                                                                                                                           1
# Hi elaine, is today's meeting confirmed?                                                                                                                                                                                                                                                                                                                                                                                                                         1
# Do you always celebrate NY's with your family ?                                                                                                                                                                                                                                                                                                                                                                                                                  1
# Al he does is moan at me if n e thin goes wrong its my fault&al de arguments r my fault&fed up of him of himso y bother? Hav 2go, thanx.xx                                                                                                                                                                                                                                                                                                                       1
# Its going good...no problem..but still need little experience to understand american customer voice...                                                                                                                                                                                                                                                                                                                                                           1
# Oh k...i'm watching here:)                                                                                                                                                                                                                                                                                                                                                                                                                                       1
# Yup. Thk of u oso boring wat.                                                                                                                                                                                                                                                                                                                                                                                                                                    1
# I like to think there's always the possibility of being in a pub later.                                                                                                                                                                                                                                                                                                                                                                                          1
# Superb Thought- "Be grateful that u dont have everything u want. That means u still have an opportunity to be happier tomorrow than u are today.":-)                                                                                                                                                                                                                                                                                                             1
# Customer place i will call you.                                                                                                                                                                                                                                                                                                                                                                                                                                  1
# I've got ten bucks, jay is being noncomittal                                                                                                                                                                                                                                                                                                                                                                                                                     1
# Oh k.i think most of wi and nz players unsold.                                                                                                                                                                                                                                                                                                                                                                                                                   1
# Sorry completely forgot * will pop em round this week if your still here?                                                                                                                                                                                                                                                                                                                                                                                        1
# So that takes away some money worries                                                                                                                                                                                                                                                                                                                                                                                                                            1
# Im sorry bout last nite it wasnt ur fault it was me, spouse it was pmt or sumthin! U 4give me? I think u shldxxxx                                                                                                                                                                                                                                                                                                                                               1
# Sounds like a plan! Cardiff is still here and still cold! I'm sitting on the radiator!                                                                                                                                                                                                                                                                                                                                                                           1
# Mm that time you dont like fun                                                                                                                                                                                                                                                                                                                                                                                                                                   1
# Also maaaan are you missing out                                                                                                                                                                                                                                                                                                                                                                                                                                  1
# Never y lei... I v lazy... Got wat? Dat day ü send me da url cant work one...                                                                                                                                                                                                                                                                                                                                                                                    1
# Name: message, Length: 4516, dtype: int64

# %%
def remove_punct_and_stopw(sms):
    
    sms_no_punct = [ch for ch in sms if ch not in string.punctuation]
    sms_no_punct = "".join(sms_no_punct).split()
    
    sms_no_punct_stopw = \
        [word.lower() for word in sms_no_punct if word.lower() not in stopwords]
        
    return sms_no_punct_stopw

# %%
df_words= df.message.apply(remove_punct_and_stopw)

# %%
df_words.head()
# Out:
# 0    [go, jurong, point, crazy, available, bugis, n...
# 1                       [ok, lar, joking, wif, u, oni]
# 2    [free, entry, 2, wkly, comp, win, fa, cup, fin...
# 3        [u, dun, say, early, hor, u, c, already, say]
# 4    [nah, dont, think, goes, usf, lives, around, t...
# Name: message, dtype: object

# %%
list_words = []
for sublist in df_words:
    for item in sublist:
        list_words.append(item)

# %%
c_words  = Counter(list_words)
df_words_top  = pd.DataFrame(c_words.most_common(30),  columns=['word', 'count'])

# %%
fig, ax = plt.subplots(figsize=(10, 6))
sns.barplot(x='word', y='count', 
            data=df_words_top, ax=ax)
plt.title("Top 30 words")
plt.xticks(rotation='vertical');

# %%
ham_im.head()
# Out:
# 0    Go until jurong point, crazy.. Available only ...
# 1                        Ok lar... Joking wif u oni...
# 3    U dun say so early hor... U c already then say...
# 4    Nah I don't think he goes to usf, he lives aro...
# 6    Even my brother is not like to speak with me. ...
# Name: message, dtype: object

# %%
df_ham_words= ham_im.apply(remove_punct_and_stopw)

# %%
type(df_ham_words)
# Out:
# pandas.core.series.Series

# %%
list_ham_words = []
for sublist in df_ham_words:
    for item in sublist:
        list_ham_words.append(item)

# %%
c_ham_words  = Counter(list_ham_words)
df_ham_words  = pd.DataFrame(c_ham_words.most_common(30),  columns=['word', 'count'])

# %%
fig, ax = plt.subplots(figsize=(10, 6))
sns.barplot(x='word', y='count', 
            data=df_ham_words, ax=ax)
plt.title("Top 30 Ham words")
plt.xticks(rotation='vertical');

# %%
df_spam_words= spam_im.apply(remove_punct_and_stopw)

# %%
list_spam_words = []
for sublist in df_spam_words:
    for item in sublist:
        list_spam_words.append(item)

# %%
c_spam_words  = Counter(list_spam_words)
df_spam_words  = pd.DataFrame(c_spam_words.most_common(30),  columns=['word', 'count'])

# %%
fig, ax = plt.subplots(figsize=(10, 6))
sns.barplot(x='word', y='count', 
            data=df_spam_words, ax=ax)
plt.title("Top 30 Spam words")
plt.xticks(rotation='vertical');
